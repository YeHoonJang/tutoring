# %% [markdown]
# # Chapter 6. 데이터 프레임의 다양한 응용

# %% [markdown]
# ## 1. 함수 매핑
# * 시리즈 또는 데이터 프레임의 개별 원소를 특정 함수에 일대일 대응 시키는 과정
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-25%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.13.20.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-25%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.13.20.png)

# %% [markdown]
# ### 1-1. 개별 원소에 함수 매핑

# %% [markdown]
# #### 시리즈 원소에 함수 매핑
# ![IMG_CDC4D31ACF36-1.jpeg](attachment:IMG_CDC4D31ACF36-1.jpeg)

# %%
import seaborn as sns

# titanic 데이터셋에서 age, fare 2개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age','fare']]
df['ten'] = 10

df.head()

# %%
# 사용자 함수 정의
def add_10(n):
    return n + 10

def add_two_obj(a, b):
    return a + b

# %%
# 시리즈 객체에 적용
# n = df['age']의 모든 원소

# sr1

# %%
# 시리즈 객체와 숫자에 적용 : 2개의 인수(시리즈 + 숫자)
# a=df['age']의 모든 원소, b=10

# sr2

# %%
# 람다 함수 활용: 시리즈 객체에 적용
# apply 함수 옵션: lambda x: add_10(x)
# x=df['age']

# sr3

# %% [markdown]
# #### 데이터프레임 원소에 함수 매핑
# ![IMG_9771A4921A9E-1.jpeg](attachment:IMG_9771A4921A9E-1.jpeg)

# %%
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age','fare']]

df.head()

# %%
# 사용자 함수 정의
def add_10(n):
    return n + 10

# %%
# 데이터프레임에 applymap()으로 add_10() 함수를 매핑 적용

# df_map

# %% [markdown]
# ### 1-2. 시리즈 객체에 함수 매핑

# %% [markdown]
# #### 데이터프레임의 각 열에 함수 매핑
# ![IMG_0111356FA179-1.jpeg](attachment:IMG_0111356FA179-1.jpeg)

# %%
# titanic 데이터셋에서 age, fare 2개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age','fare']]

# %%
# 사용자 함수 정의
def missing_value(series):
    return series.isnull()

# %%
# 데이터프레임의 각 열을 인수로 전달하면 데이터프레임을 반환
# apply 함수, missing_value, axis=0

# result

# %%
# 사용자 함수 정의
def min_max(x):    # 최대값 - 최소값
    return x.max() - x.min()

# %%
# 데이터프레임의 각 열을 인수로 전달하면 시리즈를 반환

# result

# %% [markdown]
# #### 데이터프레임의 각 행에 함수 매핑
# ![IMG_9CE4F6E1B9B4-1.jpeg](attachment:IMG_9CE4F6E1B9B4-1.jpeg)

# %%
# 사용자 함수 정의
def add_two_obj(a, b):    # 두 객체의 합
    return a + b

# %%
# 데이터프레임의 2개 열을 선택하여 적용
# x=df, a=df['age'], b=df['ten']
# apply함수, 옵션: lambda x: add_two_obj, axis=1

# df['add']

# %% [markdown]
# ### 1-3. 데이터 프레임 객체에 함수 매핑
# ![image.png](attachment:image.png)

# %%
# 각 열의 NaN 찾기 - 데이터프레임 전달하면 데이터프레임을 반환
def missing_value(x):    
    return x.isnull()    

# 각 열의 NaN 개수 반환 - 데이터프레임 전달하면 시리즈 반환
def missing_count(x):    # 
    return missing_value(x).sum()

# 데이터프레임의 총 NaN 개수 - 데이터프레임 전달하면 값을 반환
def totoal_number_missing(x):    
    return missing_count(x).sum()

# %%
# 데이터프레임에 pipe() 메소드로 함수 매핑
result_df = df.pipe(missing_value)

# %%
result_series = df.pipe(missing_count)

# %%
result_value = df.pipe(totoal_number_missing)
