# %% [markdown]
# # Chapter 2. 외부 파일 읽어오기

# %% [markdown]
# * 다양한 형태의 외부 파일 ↔️ 판다스 데이터 프레임
# * 데이터 프레임 변환 후 판다스의 모든 기능과 함수 사용 가능

# %% [markdown]
# ![IMG_C9F80C8C1CBC-1.jpeg](attachment:IMG_C9F80C8C1CBC-1.jpeg)

# %% [markdown]
# -----------

# %% [markdown]
# ## CSV 파일 불러오기
# ![IMG_FCF4EE7680DA-1.jpeg](attachment:IMG_FCF4EE7680DA-1.jpeg)

# %% [markdown]
# ### header 옵션

# %% [markdown]
# ![IMG_D5E4363386E0-1.jpeg](attachment:IMG_D5E4363386E0-1.jpeg)

# %% [markdown]
# ### index_col 옵션

# %% [markdown]
# ![IMG_6BD034D05F54-1.jpeg](attachment:IMG_6BD034D05F54-1.jpeg)

# %% [markdown]
# ## CSV 파일 불러오기 실습

# %%
import pandas as pd

# %%
# 파일경로를 찾고, 변수 file_path에 저장
# 파일 경로 : './read_csv_sample.csv'
# . 은 현재 폴더 , / 는 하위

# file_path =

# %%
# read_csv() 함수로 데이터프레임 변환
# 변수 df1에 저장

# df1 = 

print(df1)

# %%
# read_csv() 함수로 데이터프레임 변환
# 변수 df2에 저장
# header=None 옵션

# df2 =

print(df2)

# %%
# read_csv() 함수로 데이터프레임 변환
# 변수 df3에 저장
# index_col=None 옵션

# df3 = 

print(df3)

# %%
# read_csv() 함수로 데이터프레임 변환
# 변수 df4에 저장
# index_col='c0' 옵션

# df4 = 

print(df4)

# %% [markdown]
# ### read_csv( ) 옵션들

# %% [markdown]
# ![IMG_9F4F27BDEFD6-1.jpeg](attachment:IMG_9F4F27BDEFD6-1.jpeg)
# ![IMG_01F46B26CD65-1.jpeg](attachment:IMG_01F46B26CD65-1.jpeg)

# %% [markdown]
# ---------

# %% [markdown]
# ## Excel 파일 불러오기
# ![IMG_E78DED6E94DE-1.jpeg](attachment:IMG_E78DED6E94DE-1.jpeg)
#
# * csv 파일과 거의 비슷

# %% [markdown]
# ### Excel 파일 불러오기 실습

# %%
# read_excel() 함수로 데이터프레임 변환
# 파일 경로: './남북한발전전력량.xlsx'

# header=0 (default 옵션)
# df1 =

# header=None 옵션
# df2 = 

# 데이터프레임 출력
print(df1)
print('\n')
print(df2)

# %% [markdown]
# ---------

# %% [markdown]
# ## JSON 파일 불러오기
#
# * 데이터 공유를 목적으로 특수 개발된 데이터 형태
# * key:value 쌍
# * 중첩 구조
#
# ![IMG_862FFA3E7046-1.jpeg](attachment:IMG_862FFA3E7046-1.jpeg)
# ![IMG_6771F49BC6BB-1.jpeg](attachment:IMG_6771F49BC6BB-1.jpeg)

# %% [markdown]
# ### JSON 파일 불러오기 실습

# %%
# read_json() 함수로 데이터프레임 변환 
# df = 

print(df)
print('\n')
print(df.index)

# %% [markdown]
# --------

# %% [markdown]
# # 웹(Web)에서 가져오기

# %% [markdown]
# ## HTML 웹 페이지에서 표 속성 가져오기
# ![IMG_9351D6D2B1F6-1.jpeg](attachment:IMG_9351D6D2B1F6-1.jpeg)
# * HTMl 웹 페이지에 있는 <table> 태그에서 표 형식의 데이터를 모두 찾아 데이터 프레임으로 변환
# * 각각 별도의 데이터 프레임으로 변환되기 때문에 여러 개의 데이터 프레임을 원소로 갖는 리스트가 반환

# %% [markdown]
# ![IMG_BF18AC0AA27B-1.jpeg](attachment:IMG_BF18AC0AA27B-1.jpeg)

# %% [markdown]
# ### HTML 불러오기 실습

# %%
# HTML 파일 경로 or 웹 페이지 주소를 url 변수에 저장
# url 주소: './sample.html'
# HTML 웹페이지의 표(table)를 가져와서 데이터프레임으로 변환 

# tables = 

# 표(table)의 개수 확인
print(len(tables))
print('\n')

# %%
# tables 리스트의 원소를 iteration하면서 각각 화면 출력
for i in range(len(tables)):
    print("tables[%s]" % i)
    print(tables[i])
    print('\n')

# %%
# 파이썬 패키지 정보가 들어 있는 두 번째 데이터프레임을 선택하여 df 변수에 저장
# df =

print(df)

# %%
# 'name' 열을 인덱스로 지정
# set_index 사용

# df

print(df)

# %% [markdown]
# ---------

# %% [markdown]
# ## 웹 스크래핑
# * BeautifulSoup 등의 웹 스크래핑 도구로 수집한 데이터를 데이터 프레임으로 변환
# * 스크래핑한 내용 ➡️ 파이썬 리스트/딕셔너리 ➡️ 판다스 데이터 프레임

# %% [markdown]
# ![IMG_CB5D284421A3-1.jpeg](attachment:IMG_CB5D284421A3-1.jpeg)

# %% [markdown]
# ------------

# %% [markdown]
# # API 활용하여 데이터 수집하기
# * 인터넷 서비스 업체에서 제공하는 API 를 활용하여 데이터 수집 ➡️ 판다스 데이터 프레임 변환
# * 대부분 csv, json, xml 들 판다스가 읽기 쉬운 자료형태로 제공
# * 실습 생략

# %% [markdown]
# ------------

# %% [markdown]
# # 데이터 저장하기

# %% [markdown]
# ## CSV 파일로 저장하기
# ![IMG_87FBFD8E2726-1.jpeg](attachment:IMG_87FBFD8E2726-1.jpeg)

# %% [markdown]
# ### CSV 파일로 저장하기 실습

# %%
# 판다스 DataFrame() 함수로 데이터프레임 변환 
# 변수 df에 저장 
data = {'name' : [ 'Jerry', 'Riah', 'Paul'],
        'algol' : [ "A", "A+", "B"],
        'basic' : [ "C", "B", "B+"],
        'c++' : [ "B+", "C", "C+"],
        }

#df =

# %%
# set_index 를 사용하여 'name'을 인덱스로 지정 

# df.
print(df)

# %%
# to_csv() 메소드를 사용하여 CSV 파일로 내보내기
# 파열명은 df_sample.csv로 저장

# df

# %% [markdown]
# -----------

# %% [markdown]
# ## JSON 파일로 저장하기
# ![IMG_7DEDCA9BFE22-1.jpeg](attachment:IMG_7DEDCA9BFE22-1.jpeg)

# %% [markdown]
# ### JSON 파일로 저장하기 실습

# %%
# 판다스 DataFrame() 함수로 데이터프레임 변환
# 변수 df에 저장 
data = {'name' : [ 'Jerry', 'Riah', 'Paul'],
        'algol' : [ "A", "A+", "B"],
        'basic' : [ "C", "B", "B+"],
        'c++' : [ "B+", "C", "C+"],
        }

#df =

# %%
# set_index 를 사용하여 'name'을 인덱스로 지정 

# df.
print(df)

# %%
# to_json() 메소드를 사용하여 JSON 파일로 내보내기
# 파열명은 df_sample.json로 저장

#df

# %% [markdown]
# -----------

# %% [markdown]
# ## Excel 파일로 저장하기
# ![IMG_C78AAC4A9379-1.jpeg](attachment:IMG_C78AAC4A9379-1.jpeg)

# %%
# 판다스 DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
data = {'name' : [ 'Jerry', 'Riah', 'Paul'],
        'algol' : [ "A", "A+", "B"],
        'basic' : [ "C", "B", "B+"],
        'c++' : [ "B+", "C", "C+"],
        }

# df

# %%
# set_index 를 사용하여 'name'을 인덱스로 지정 

# df.
print(df)

# %%
# to_excel() 메소드를 사용하여 엑셀 파일로 내보내기
# 파열명은 df_sample.xlsx로 저장

#df

# %% [markdown]
# -------

# %% [markdown]
# ## 여러 개의 데이터 프레임을 하나의 Excel 파일로 저장하기
# ![IMG_5868F42754DD-1.jpeg](attachment:IMG_5868F42754DD-1.jpeg)
# * 엑셀 워크북 개체를 생성
# * to_excel() 함수로 워크북에 시트 추가

# %%
# 판다스 DataFrame() 함수로 데이터프레임 변환. 변수 df1, df2에 저장 
data1 = {'name' : [ 'Jerry', 'Riah', 'Paul'],
         'algol' : [ "A", "A+", "B"],
         'basic' : [ "C", "B", "B+"],
          'c++' : [ "B+", "C", "C+"]}

# df1 =

# %%
#set_index 를 사용하여 'name'을 인덱스로 지정

# df1
print(df1)

# %%
data2 = {'c0':[1,2,3], 
         'c1':[4,5,6], 
         'c2':[7,8,9], 
         'c3':[10,11,12], 
         'c4':[13,14,15]}


# df2 =

# %%
#set_index 를 사용하여 'name'을 인덱스로 지정


#df2.
print(df2)

# %%
# ExcelWriter 로 워크북 생성
# 엑셀파일명은 "df_excelwriter.xlsx"

# writer =

# %%
# df1을 'sheet1'으로, df2를 'sheet2'로 저장

# df1
# df2

# %%
writer.save()

# %% [markdown]
# ![IMG_ACA3B105513B-1.jpeg](attachment:IMG_ACA3B105513B-1.jpeg)
