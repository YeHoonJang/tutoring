# %% [markdown]
# # 건강검진 데이터를 활용하여 비만 여부를 예측해 보아요!
# 데이터 출처: https://www.data.go.kr/data/15007122/fileData.do

# %% [markdown]
# ## 라이브러리 불러오기

# %%
# import warnings
# warnings.filterwarnings(action='ignore')

# 머신러닝 모델 학습 관련
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## 데이터 불러오기

# %%
df.head()

# %%
df.columns.values

# %%
# new_cols 원소 소문자로 바꾸기

new_cols = ["HCHK_YEAR", "IDV_ID", "SIDO", "SEX", "AGE_GROUP", "HEIGHT", "WEIGHT", "WAIST", "SIGHT_LEFT", 
            "SIGHT_RIGHT", "HEAR_LEFT", "HEAR_RIGHT", "BP_HIGH", "BP_LWST", "BLDS", "TOT_CHOLE", "TRIGLYCERIDE",
            "HDL_CHOLE", "LDL_CHOLE", "HMG", "OLIG_PROTE_CD", "CREATININE", "SGOT_AST", "SGPT_ALT", "GAMMA_GTP",
            "SMK_STAT_TYPE_CD", "DRK_YN", "HCHK_OE_INSPEC_YN", "CRS_YN", "TTH_MSS_YN", "ODT_TRB_YN", "WSDM_DIS_YN", 
            "TTR_YN", "DATA_STD__DT"]

# %% [markdown]
# ## colums 이름 바꾸기

# %%
df.head()

# %% [markdown]
# ## 일부 컬럼 제거

# %%
drop_cols = ['hchk_year','idv_id','sido', 'hchk_oe_inspec_yn', 'crs_yn', 'tth_mss_yn', 'odt_trb_yn',
             'wsdm_dis_yn', 'ttr_yn', 'data_std__dt', 'sight_left', 'sight_right', 'hear_left', 'hear_right']


df.head()

# %% [markdown]
# ## null 값 채우기

# %%
# df 정보 확인

# %%
# for문 이용하여 각 컬럼의 null 데이터 개수가 500,000 미만이면 중앙값 값 대체, 500,000 개 이상이면 drop_cols에 컬럼 이름 저장
# for문 완료시 drop_cols 이용하여 Nan 값이 있는 row 삭제

drop_cols = []
for column in df.columns:
    
df.shape

# %%
# null 값 처리 됐는지 다시 한 번 df 정보 확인

# %% [markdown]
# ## bmi 컬럼 추가
# BMI = 체중(kg) / (키(m) * 키(m))

# %%
# bmi 공식 이용하여 bmi 값 추출 후 반올림하여 정수형으로 값 생성 후 bmi 컬럼에 저장
# 키와 체중 컬럼 삭제 


df.head()

# %% [markdown]
# ## 비만 여부 컬럼 추가하기

# %%
# 비만 여부 is_obesity 컬럼 0으로 초기화
# bmi 가 30 이상이면 is_obesity 값 1로 갱신


df.head()

# %% [markdown]
# ## 데이터 분할

# %%
# 비만 여부가 종속 변수, 나머지 독립 변수
x
y

x.shape, y.shape

# %% [markdown]
# ## 학습, 검증 데이터 분리

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.3, random_state=42)

print(x_train.shape, x_valid.shape, y_train.shape, y_valid.shape)

# %% [markdown]
# ## 모델 학습

# %%
# LogisticRegression 클래스 호출
# lr 모델 학습

lr =

# %%
# 학습된 모델에 검증 데이터로 성능 확인

y_val_pred =

accuracy_score(y_valid, y_val_pred)

# %% [markdown]
# ![99DC064C5BE056CE10.png](attachment:99DC064C5BE056CE10.png)
# ![998E18405E7E16BB36.png](attachment:998E18405E7E16BB36.png)

# %%
print(classification_report(y_valid, y_val_pred))

# %% [markdown]
# ## 데이터 분포 확인

# %%
# 종속 변수의 데이터 분포 확인

df["is_obesity"]

# %% [markdown]
# ## 데이터 resampling

# %%
# !pip install imbalanced_learn

# %%
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# ## Undersampling

# %%
undersample = RandomUnderSampler(sampling_strategy='')

# %%
# undersampling 실행

print(Counter(y))
x_under, y_under = 
print(Counter(y_under))

# %% [markdown]
# ## 데이터 분할 및 학습

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_under, y_under, test_size=0.3, random_state=42)

print(x_train.shape, x_valid.shape, y_train.shape, y_valid.shape)

# %%
lr 


y_val_pred 

accuracy_score(y_valid, y_val_pred)

# %%
print(classification_report(y_valid, y_val_pred))

# %% [markdown]
# ## Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='')

# %%
# oversampling 실행

print(Counter(y))
x_over, y_over = 
print(Counter(y_over))

# %% [markdown]
# ## 데이터 분할 및 학습

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_over, y_over, test_size=0.3, random_state=42)

print(x_train.shape, x_valid.shape, y_train.shape, y_valid.shape)

# %%
lr 


y_val_pred 

accuracy_score(y_valid, y_val_pred)

# %%
print(classification_report(y_valid, y_val_pred))
